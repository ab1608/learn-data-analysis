# %% [markdown]
# # Sales analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Merge 12 months of data into a single file
# - Currently, the data exists as csv files per month.
# - I would like to merge the contents of the csv files into one file to serve as an *annual* file.

# %%
import os

# Directory path
csv_files_path = "/Users/abrahambriones/Library/CloudStorage/OneDrive-Personal/Documents/LearnDataAnalysis/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data"

# Change current working directory to the csv_files_path
os.chdir(csv_files_path)

# A list of all .csv files
csv_files = os.listdir(csv_files_path)

# Combine all files in the list and save to a new csv file
df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
df.to_csv('Sales_Annual_2019_v2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/th/rzp35bqs0q13cj8krjh_q7vm0000gn/T/ipykernel_8514/3311728451.py in <module>
#      11
#      12 # Combine all files in the list and save to a new csv file
# ---> 13 df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
#      14 df.to_csv('Sales_Annual_2019_v2.csv', index=False)
#
# /var/folders/th/rzp35bqs0q13cj8krjh_q7vm0000gn/T/ipykernel_8514/3311728451.py in <listcomp>(.0)
#      11
#      12 # Combine all files in the list and save to a new csv file
# ---> 13 df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
#      14 df.to_csv('Sales_Annual_2019_v2.csv', index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte

# %%
df = pd.read_csv('Sales_Annual_2019_v2.csv')
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
df.dtypes # Two columns should be change to numerical representations
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"], errors='coerce')
df["Price Each"] = pd.to_numeric(df["Price Each"], errors='coerce')

# %%
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# ## Task 1: Determine which month produced the most sales and report the revenue.
# - It will be useful to create a month column

# %% [markdown]
# ### Create a month column

# %%
# Make a new OrdeDate column with datatime objects
frmt = '%m/%d/%y %H:%M'
df['Order Date (datetime)'] =  pd.to_datetime(df['Order Date'], errors='coerce', format=frmt)

# Extract the months from the datetime column
df['Month'] = df['Order Date (datetime)'].dt.month
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/th/rzp35bqs0q13cj8krjh_q7vm0000gn/T/ipykernel_8514/1704225985.py in <module>
#       5 # Extract the months from the datetime column
#       6 df['Month'] = df['Order Date (datetime)'].dt.month
# ----> 7 df['Month'] = df['Month'].astype('int32')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
# New month column exists
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301
#
#   Order Date (datetime)  Month
# 0   2019-12-30 00:01:00   12.0
# 1   2019-12-29 07:03:00   12.0
# 2   2019-12-12 18:21:00   12.0
# 3   2019-12-22 15:13:00   12.0
# 4   2019-12-18 12:38:00   12.0

# %% [markdown]
# #### Let's look for NaN values

# %%
df.isna().sum()

# %%
df[df.isna().any(axis=1)]
# Out:
#          Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254      Order ID  Product               NaN         NaN  Order Date
# 264           NaN      NaN               NaN         NaN         NaN
# 648           NaN      NaN               NaN         NaN         NaN
# 680           NaN      NaN               NaN         NaN         NaN
# 705      Order ID  Product               NaN         NaN  Order Date
# ...           ...      ...               ...         ...         ...
# 1234443       NaN      NaN               NaN         NaN         NaN
# 1234462       NaN      NaN               NaN         NaN         NaN
# 1234535       NaN      NaN               NaN         NaN         NaN
# 1235107  Order ID  Product               NaN         NaN  Order Date
# 1235155       NaN      NaN               NaN         NaN         NaN
#
#          Purchase Address Order Date (datetime)  Month
# 254      Purchase Address                   NaT    NaN
# 264                   NaN                   NaT    NaN
# 648                   NaN                   NaT    NaN
# 680                   NaN                   NaT    NaN
# 705      Purchase Address                   NaT    NaN
# ...                   ...                   ...    ...
# 1234443               NaN                   NaT    NaN
# 1234462               NaN                   NaT    NaN
# 1234535               NaN                   NaT    NaN
# 1235107  Purchase Address                   NaT    NaN
# 1235155               NaN                   NaT    NaN
#
# [1049475 rows x 8 columns]

# %%
df.shape

# %% [markdown]
# - Out of the 1,235,425 rows, 1,049,475 rows are compleltely blank

# %%
df = df.dropna(axis=0)

# %% [markdown]
# #### All NaN values have been deleted

# %%
df.isna().sum()
# Out:
# Order ID                 0
# Product                  0
# Quantity Ordered         0
# Price Each               0
# Order Date               0
# Purchase Address         0
# Order Date (datetime)    0
# Month                    0
# dtype: int64

# %% [markdown]
# ### Create a sales column
# - sales is quantity * priceeach

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301
#
#   Order Date (datetime)  Month    Sales
# 0   2019-12-30 00:01:00     12  1700.00
# 1   2019-12-29 07:03:00     12   600.00
# 2   2019-12-12 18:21:00     12    11.95
# 3   2019-12-22 15:13:00     12   149.99
# 4   2019-12-18 12:38:00     12    11.95

# %% [markdown]
# ## Task 1: Determine which month produced the most sales and report the revenue.

# %%
monthly_sales = df.groupby(by=['Month']).sum()
monthly_sales.sort_values(by='Sales')
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1               10903.0  1811768.38  1822256.73
# 9               13109.0  2084992.09  2097560.13
# 2               13449.0  2188884.72  2202022.42
# 8               13448.0  2230345.42  2244467.88
# 6               15253.0  2562025.61  2577802.26
# 7               16072.0  2632539.56  2647775.76
# 3               17005.0  2791207.83  2807100.38
# 5               18667.0  3135125.13  3152606.75
# 11              19798.0  3180600.68  3199603.20
# 4               20558.0  3367671.02  3390670.24
# 10              22703.0  3715554.83  3736726.88
# 12              28114.0  4588415.41  4613443.34

# %% [markdown]
# It can be seen that December reported the most sales while January reported the least sales.

# %%
### Let's visualize these results with a bar plot
### Example with SNS and Matplotlib
x_axis = monthly_sales.index
y_axis = monthly_sales['Sales']
sns.barplot(x=x_axis, y=y_axis)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Sales'>

# %%
plt.bar(x_axis, y_axis)
plt.xticks(x_axis)
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Task 2: Which city had the highest number of sales?
# - Will be useful to create a city column

# %%
df['City'] = [address.split(', ')[1] for address in df['Purchase Address']]
df['State'] = [address.split(", ")[2].split()[0] for address in df['Purchase Address']]
df["City (State)"] = df["City"] + " (" + df["State"] + ")"

# Alternative method 
# df['City'] = df['Purchase Addresss'].apply(lambda x: x.split(', ')[1])

# %%
# City column has been created
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301
#
#   Order Date (datetime)  Month    Sales           City State  \
# 0   2019-12-30 00:01:00     12  1700.00  New York City    NY
# 1   2019-12-29 07:03:00     12   600.00  New York City    NY
# 2   2019-12-12 18:21:00     12    11.95  New York City    NY
# 3   2019-12-22 15:13:00     12   149.99  San Francisco    CA
# 4   2019-12-18 12:38:00     12    11.95        Atlanta    GA
#
#          City (State)
# 0  New York City (NY)
# 1  New York City (NY)
# 2  New York City (NY)
# 3  San Francisco (CA)
# 4        Atlanta (GA)

# %%
city_sales = df.groupby(by=['City (State)']).sum()
city_sales
# Out:
#                     Quantity Ordered  Price Each   Month       Sales
# City (State)
# Atlanta (GA)                 16602.0  2779908.20  104794  2795498.58
# Austin (TX)                  11153.0  1809873.61   69829  1819581.75
# Boston (MA)                  22528.0  3637409.77  141112  3661642.01
# Dallas (TX)                  16730.0  2752627.82  104620  2767975.40
# Los Angeles (CA)             33289.0  5421435.23  208325  5452570.80
# New York City (NY)           27932.0  4635370.83  175741  4664317.43
# Portland (ME)                 2750.0   447189.25   17144   449758.27
# Portland (OR)                11303.0  1860558.22   70621  1870732.34
# San Francisco (CA)           50239.0  8211461.74  315520  8262203.91
# Seattle (WA)                 16553.0  2733296.01  104941  2747755.48

# %% [markdown]
# It can be seen that San Francisco reported the most sales while Portland, Maine reported the least sales

# %%
x_axis = city_sales.index
y_axis = city_sales['Sales']
plt.bar(x_axis, y_axis)
plt.xticks(x_axis, rotation='vertical')
plt.xlabel("City")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Task 3: At what time should advertisements be aired to sell the most product?
# - Will be useful to create an Hour column

# %%
# Create a time column
df['Hour'] = df['Order Date (datetime)'].dt.hour
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301
#
#   Order Date (datetime)  Month    Sales           City State  \
# 0   2019-12-30 00:01:00     12  1700.00  New York City    NY
# 1   2019-12-29 07:03:00     12   600.00  New York City    NY
# 2   2019-12-12 18:21:00     12    11.95  New York City    NY
# 3   2019-12-22 15:13:00     12   149.99  San Francisco    CA
# 4   2019-12-18 12:38:00     12    11.95        Atlanta    GA
#
#          City (State)  Hour
# 0  New York City (NY)     0
# 1  New York City (NY)     7
# 2  New York City (NY)    18
# 3  San Francisco (CA)    15
# 4        Atlanta (GA)    12

# %%
hourly_sales = df.groupby(by='Hour').count()[['Product']]
hourly_sales
# Out:
#       Product
# Hour
# 0        3910
# 1        2350
# 2        1243
# 3         831
# 4         854
# 5        1321
# 6        2482
# 7        4011
# 8        6256
# 9        8748
# 10      10944
# 11      12411
# 12      12587
# 13      12129
# 14      10984
# 15      10175
# 16      10384
# 17      10899
# 18      12280
# 19      12905
# 20      12228
# 21      10921
# 22       8822
# 23       6275

# %%
x_axis = hourly_sales.index
y_axis = hourly_sales['Product']
plt.plot(x_axis, y_axis)
plt.xticks(x_axis, rotation='vertical')
plt.xlabel("Hour")
plt.ylabel("Product Units")
# Out:
# Text(0, 0.5, 'Product Units')

# %% [markdown]
# It seems that most products are sold between the hours of 6pm and 8pm.

# %% [markdown]
# ## Task 4: What products are most often sold together?

# %%
# Let's get the rows who have the same order IDs so that we can find items 
# that were sold together
same_order_id = df[df.duplicated(subset=['Order ID'], keep=False)]
same_order_id.head(20)

same_order_id['Grouped Products'] = same_order_id.groupby('Order ID')['Product'].transform(lambda x: ', '.join(x))
# Out:
# /var/folders/th/rzp35bqs0q13cj8krjh_q7vm0000gn/T/ipykernel_8514/3907463101.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   same_order_id['Grouped Products'] = same_order_id.groupby('Order ID')['Product'].transform(lambda x: ', '.join(x))

# %%
# Now we have a column with the pairs of products that share the same ID
same_order_id.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone               1.0      600.00
# 17   295681        USB-C Charging Cable               1.0       11.95
# 18   295681  Bose SoundSport Headphones               1.0       99.99
# 19   295681            Wired Headphones               1.0       11.99
# 36   295698             Vareebadd Phone               1.0      400.00
#
#         Order Date                     Purchase Address Order Date (datetime)  \
# 16  12/25/19 12:37          79 Elm St, Boston, MA 02215   2019-12-25 12:37:00
# 17  12/25/19 12:37          79 Elm St, Boston, MA 02215   2019-12-25 12:37:00
# 18  12/25/19 12:37          79 Elm St, Boston, MA 02215   2019-12-25 12:37:00
# 19  12/25/19 12:37          79 Elm St, Boston, MA 02215   2019-12-25 12:37:00
# 36  12/13/19 14:32  175 1st St, New York City, NY 10001   2019-12-13 14:32:00
#
#     Month   Sales           City State        City (State)  Hour  \
# 16     12  600.00         Boston    MA         Boston (MA)    12
# 17     12   11.95         Boston    MA         Boston (MA)    12
# 18     12   99.99         Boston    MA         Boston (MA)    12
# 19     12   11.99         Boston    MA         Boston (MA)    12
# 36     12  400.00  New York City    NY  New York City (NY)    14
#
#                                      Grouped Products
# 16  Google Phone, USB-C Charging Cable, Bose Sound...
# 17  Google Phone, USB-C Charging Cable, Bose Sound...
# 18  Google Phone, USB-C Charging Cable, Bose Sound...
# 19  Google Phone, USB-C Charging Cable, Bose Sound...
# 36              Vareebadd Phone, USB-C Charging Cable

# %%
# Let's drop the duplicate entries so that we have unique group product pairs
same_order_id = same_order_id[['Order ID', 'Grouped Products']].drop_duplicates()
same_order_id
# Out:
#         Order ID                                   Grouped Products
# 16        295681  Google Phone, USB-C Charging Cable, Bose Sound...
# 36        295698              Vareebadd Phone, USB-C Charging Cable
# 42        295703  AA Batteries (4-pack), Bose SoundSport Headphones
# 66        295726                   iPhone, Lightning Charging Cable
# 76        295735  iPhone, Apple Airpods Headphones, Wired Headph...
# ...          ...                                                ...
# 1235373   222863       27in FHD Monitor, Bose SoundSport Headphones
# 1235379   222868                   iPhone, Apple Airpods Headphones
# 1235394   222882    Apple Airpods Headphones, AA Batteries (4-pack)
# 1235397   222884                 Google Phone, USB-C Charging Cable
# 1235417   222903                   iPhone, Lightning Charging Cable
#
# [7136 rows x 2 columns]

# %%
# Source: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary

from itertools import combinations
from collections import Counter

count = Counter()

# Split the group products column into a list to use with the libraries
# Change the int value to view groups of 2, 3, etc.
for prod in same_order_id['Grouped Products']:
    prod_list = prod.split(', ')
    count.update(combinations(prod_list, 2))
    
print(count.most_common(3))
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005), (('Google Phone', 'USB-C Charging Cable'), 987), (('iPhone', 'Wired Headphones'), 447)]

# %% [markdown]
# ## Task 5: Which product is most often sold?

# %%
product_sales = df.groupby(['Product']).sum()
product_sales
# Out:
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# 20in Monitor                          4129.0   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                6244.0  2429637.70   44440  2435097.56
# 27in FHD Monitor                      7550.0  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                6199.0  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                27635.0    79015.68  145558   106118.40
# AAA Batteries (4-pack)               31017.0    61716.59  146370    92740.83
# Apple Airpods Headphones             15661.0  2332350.00  109477  2349150.00
# Bose SoundSport Headphones           13457.0  1332366.75   94113  1345565.43
# Flatscreen TV                         4819.0  1440000.00   34224  1445700.00
# Google Phone                          5532.0  3315000.00   38305  3319200.00
# LG Dryer                               646.0   387600.00    4383   387600.00
# LG Washing Machine                     666.0   399600.00    4523   399600.00
# Lightning Charging Cable             23217.0   323787.10  153092   347094.15
# Macbook Pro Laptop                    4728.0  8030800.00   33548  8037600.00
# ThinkPad Laptop                       4130.0  4127958.72   28950  4129958.70
# USB-C Charging Cable                 23975.0   261740.85  154819   286501.25
# Vareebadd Phone                       2068.0   826000.00   14309   827200.00
# Wired Headphones                     20557.0   226395.18  133397   246478.43
# iPhone                                6849.0  4789400.00   47941  4794300.00
#
#                               Hour
# Product
# 20in Monitor                 58764
# 27in 4K Gaming Monitor       90916
# 27in FHD Monitor            107540
# 34in Ultrawide Monitor       89076
# AA Batteries (4-pack)       298342
# AAA Batteries (4-pack)      297332
# Apple Airpods Headphones    223304
# Bose SoundSport Headphones  192445
# Flatscreen TV                68815
# Google Phone                 79479
# LG Dryer                      9326
# LG Washing Machine            9785
# Lightning Charging Cable    312529
# Macbook Pro Laptop           68261
# ThinkPad Laptop              59746
# USB-C Charging Cable        314645
# Vareebadd Phone              29472
# Wired Headphones            271720
# iPhone                       98657

# %%
x_axis = product_sales.index
y_axis = product_sales['Quantity Ordered']
plt.bar(x_axis, y_axis)
plt.xticks(x_axis, rotation='vertical')
plt.xlabel("Product")
plt.ylabel("Product Units")
# Out:
# Text(0, 0.5, 'Product Units')

# %%
df.to_csv('Annual_Sales_2019_v3.csv')
