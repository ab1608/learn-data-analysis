# %%
import pandas as pd;
import numpy as np;

# %%
csv_path = "/Users/abrahambriones/Library/CloudStorage/OneDrive-Personal/Documents/LearnDataAnalysis/SampleSQLProject/CovidDeaths.csv"
df = pd.read_csv(csv_path)
df
# Out:
#       iso_code continent     location     date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/20          1.0        1.0
# 1          AFG      Asia  Afghanistan  2/25/20          1.0        0.0
# 2          AFG      Asia  Afghanistan  2/26/20          1.0        0.0
# 3          AFG      Asia  Afghanistan  2/27/20          1.0        0.0
# 4          AFG      Asia  Afghanistan  2/28/20          1.0        0.0
# ...        ...       ...          ...      ...          ...        ...
# 85166      ZWE    Africa     Zimbabwe  4/26/21      38102.0       16.0
# 85167      ZWE    Africa     Zimbabwe  4/27/21      38164.0       62.0
# 85168      ZWE    Africa     Zimbabwe  4/28/21      38191.0       27.0
# 85169      ZWE    Africa     Zimbabwe  4/29/21      38235.0       44.0
# 85170      ZWE    Africa     Zimbabwe  4/30/21      38257.0       22.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.fillna(r"\N", inplace=True)

# %%
df.to_csv(csv_path)

# %%
csv_path2 = "/Users/abrahambriones/Library/CloudStorage/OneDrive-Personal/Documents/LearnDataAnalysis/SampleSQLProject/CovidVaccinations.csv"
df2 = pd.read_csv(csv_path2)
df2
# Out:
#       iso_code continent     location     date  new_tests  total_tests  \
# 0          AFG      Asia  Afghanistan  2/24/20        NaN          NaN
# 1          AFG      Asia  Afghanistan  2/25/20        NaN          NaN
# 2          AFG      Asia  Afghanistan  2/26/20        NaN          NaN
# 3          AFG      Asia  Afghanistan  2/27/20        NaN          NaN
# 4          AFG      Asia  Afghanistan  2/28/20        NaN          NaN
# ...        ...       ...          ...      ...        ...          ...
# 85166      ZWE    Africa     Zimbabwe  4/26/21     1495.0     484446.0
# 85167      ZWE    Africa     Zimbabwe  4/27/21     2355.0     486801.0
# 85168      ZWE    Africa     Zimbabwe  4/28/21     2025.0     488826.0
# 85169      ZWE    Africa     Zimbabwe  4/29/21        NaN          NaN
# 85170      ZWE    Africa     Zimbabwe  4/30/21        NaN          NaN
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# ...

# %%
df2.fillna(r"\N", inplace=True)

# %%
df2
# Out:
#       iso_code continent     location     date new_tests total_tests  \
# 0          AFG      Asia  Afghanistan  2/24/20        \N          \N
# 1          AFG      Asia  Afghanistan  2/25/20        \N          \N
# 2          AFG      Asia  Afghanistan  2/26/20        \N          \N
# 3          AFG      Asia  Afghanistan  2/27/20        \N          \N
# 4          AFG      Asia  Afghanistan  2/28/20        \N          \N
# ...        ...       ...          ...      ...       ...         ...
# 85166      ZWE    Africa     Zimbabwe  4/26/21    1495.0    484446.0
# 85167      ZWE    Africa     Zimbabwe  4/27/21    2355.0    486801.0
# 85168      ZWE    Africa     Zimbabwe  4/28/21    2025.0    488826.0
# 85169      ZWE    Africa     Zimbabwe  4/29/21        \N          \N
# 85170      ZWE    Africa     Zimbabwe  4/30/21        \N          \N
#
#       total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# ...

# %%
df2.to_csv(csv_path2)

# %%
df2
# Out:
#       iso_code continent     location     date new_tests total_tests  \
# 0          AFG      Asia  Afghanistan  2/24/20        \N          \N
# 1          AFG      Asia  Afghanistan  2/25/20        \N          \N
# 2          AFG      Asia  Afghanistan  2/26/20        \N          \N
# 3          AFG      Asia  Afghanistan  2/27/20        \N          \N
# 4          AFG      Asia  Afghanistan  2/28/20        \N          \N
# ...        ...       ...          ...      ...       ...         ...
# 85166      ZWE    Africa     Zimbabwe  4/26/21    1495.0    484446.0
# 85167      ZWE    Africa     Zimbabwe  4/27/21    2355.0    486801.0
# 85168      ZWE    Africa     Zimbabwe  4/28/21    2025.0    488826.0
# 85169      ZWE    Africa     Zimbabwe  4/29/21        \N          \N
# 85170      ZWE    Africa     Zimbabwe  4/30/21        \N          \N
#
#       total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# ...
